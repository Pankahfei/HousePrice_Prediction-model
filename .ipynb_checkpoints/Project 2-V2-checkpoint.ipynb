# %% [markdown]
# ### Project 2 - Ames Housing Data and Kaggle Challenge
# Creating a regression model based on the Ames Housing Dataset. This model will predict the price of a house at sale.
# Generate regression model using the training data
# - train-test split
# - cross-validation / grid searching for hyperparameters
# - strong exploratory data analysis to question correlation and relationship across predictive variables
# - Are categorical variables one-hot encoded?
# - Does the student investigate or manufacture features with linear relationships to the target?
# - Have the data been scaled appropriately?
# - Does the student properly split and/or sample the data for validation/training purposes?
# - Does the student utilize feature selection to remove noisy or multi-collinear features?
# - Does the student test and evaluate a variety of models to identify a production algorithm (**AT MINIMUM:** linear regression, lasso, and ridge)?
# - Does the student accurately identify and explain the baseline score?
# - Does the student defend their choice of production model relevant to the data at hand and the problem?
# - Does the student explain how the model works and evaluate its performance successes/downfalls?
# - code that reproducibly and consistently applies feature transformation (such as the preprocessing library)
# - Predict the values for your target column in the test dataset

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet, LogisticRegression,LassoCV
from sklearn.neighbors import KNeighborsClassifier
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split,cross_val_score, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from scipy.stats import norm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.compose import ColumnTransformer

# %% [markdown]
# ## EDA
# - **Read the data dictionary.**
# - Determine _what_ missing values mean.
# - Figure out what each categorical value represents.
# - Identify outliers.
# - Consider whether discrete values are better represented as categorical or continuous. (Are relationships to the target linear?)

# %%
## Read the data

df_train = pd.read_csv('datasets/train.csv')
df_test = pd.read_csv('datasets/test.csv')

# %%
df_train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0          NaN        0       3    2010        WD      130500
# 1          NaN        0       4    2009        WD      220000
# 2          NaN        0       1    2010        WD      109000
# 3          NaN        0       4    2010        WD      174000
# 4          NaN        0       3    2010        WD      138500
#
# [5 rows x 81 columns]

# %%
original_train_row = df_train.shape[0]
print("train shape:",df_train.shape, "test shape",df_test.shape)
# Out:
# train shape: (2051, 81) test shape (878, 80)

# %%
## Id and PID columns are not needed

train_id = df_train['Id']
test_id = df_test['Id']
df_train = df_train.drop(columns=['Id','PID'])
df_test = df_test.drop(columns=['Id','PID'])

# %%
## Idendify Null values

df_null = pd.DataFrame((100*df_train.isnull().sum()/len(df_train)),columns=['percentage']).sort_values(by='percentage',ascending=False)
df_null = df_null[df_null['percentage']>0]
df_null.head()
# Out:
#               percentage
# Pool QC        99.561190
# Misc Feature   96.830814
# Alley          93.174061
# Fence          80.497318
# Fireplace Qu   48.756704

# %%
f, ax = plt.subplots(figsize=(10,5))
sns.barplot(x=df_null.index, y=[j for value in df_null.values for j in value],palette='Blues_r')
plt.xticks(rotation='90')
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percentage of missing values', fontsize=15)
plt.title('Percentage of missing data by feature', fontsize=15)
plt.axhline(y = 3, color = 'r', linestyle = '-')

# %%
y = df_train['SalePrice']

##to check whether the output is normally distributed - balance data

(mu,sigma) = norm.fit(y)
print(f'mu = {round(mu,2)}, sigma = {round(sigma,2)}, skew = {y.skew()}')
f, ax = plt.subplots(figsize=(10,5))
ax = sns.distplot(y, fit=norm)
plt.xlabel('SalePrice', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.title('Distribution of Housing Sale Price', fontsize=15)
plt.show()
# Out:
# mu = 181469.7, sigma = 79239.34, skew = 1.5575514385863427
# C:\Users\pkfei\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Exploratory Visualizations
# - Look at distributions.
# - Look at correlations.
# - Look at relationships to target (scatter plots for continuous, box plots for categorical).

# %%
f, ax = plt.subplots(figsize=(20,20))
sns.heatmap(df_train.corr(),cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
df_corr = df_train.corr()
top_corr_features = list(df_corr[(df_corr['SalePrice']>0.6)&(df_corr['SalePrice']!=1)].index)
top_corr_features.append('Year Built')

# %%
top_corr_plot = pd.concat([y,df_train[top_corr_features]],axis=1)
sns.pairplot(data=top_corr_plot)

# %%
continuous_outliers = ['Total Bsmt SF','1st Flr SF','Gr Liv Area','Garage Area','Year Built' ]

fig, ax = plt.subplots(figsize=(12, 12))
plt.subplots_adjust(right=2)
plt.subplots_adjust(top=2)

for i, feature in enumerate(continuous_outliers,1):

    plt.subplot(len(continuous_outliers), 2, i)
    sns.scatterplot(x=feature, y='SalePrice', palette='Blues', data=top_corr_plot)     
    plt.xlabel('{}'.format(feature), size=15,labelpad=12.5)
    plt.ylabel('SalePrice', size=15, labelpad=12.5)
    
    for j in range(2):
        plt.tick_params(axis='x', labelsize=15)
        plt.tick_params(axis='y', labelsize=15)
        
plt.show()

# %%
Categorical_outliers = ['Overall Qual','Garage Cars']

fig,ax = plt.subplots(figsize=(20,12))
plt.subplots_adjust(right=2)
plt.subplots_adjust(top=2)

for i, feature in enumerate(Categorical_outliers,1):
    
    plt.subplot(len(Categorical_outliers), 1, i)
    sns.boxplot(x=feature, y='SalePrice', palette='Blues', data=top_corr_plot)     
    plt.xlabel('{}'.format(feature), size=25,labelpad=12.5)
    plt.ylabel('SalePrice', size=25, labelpad=12.5)
    for j in range(2):
        plt.tick_params(axis='x', labelsize=25)
        plt.tick_params(axis='y', labelsize=25)

plt.show()

# %%
#Consider whether discrete values are better represented as categorical or continuous. (Are relationships to the target linear?)

# %% [markdown]
# MS SubClass, YrSold, MoSold should be a categorical feature (convert to str)

# %% [markdown]
# ## Data Cleaning
# - Decide how to impute null values.
# - Decide how to handle outliers.
# - Do you want to combine any features?
# - Do you want to have interaction terms?
# - Do you want to manually drop collinear features?

# %%
columns_dropped = list(df_null[df_null['percentage']>3].index)
df_train.drop(columns=columns_dropped,inplace=True)
null_to_drop = list(df_null[df_null['percentage']<=3].index)
for i, feature in enumerate(null_to_drop):
    df_train = df_train.drop(df_train[df_train[feature].isnull()].index)

# %%
df_train.isnull().sum().sort_values(ascending=False)
# Out:
# MS SubClass       0
# Gr Liv Area       0
# Kitchen AbvGr     0
# Bedroom AbvGr     0
# Half Bath         0
#                  ..
# Bsmt Cond         0
# Bsmt Exposure     0
# BsmtFin Type 1    0
# BsmtFin SF 1      0
# SalePrice         0
# Length: 68, dtype: int64

# %%
df_train.drop(df_train[(df_train['SalePrice']<300000)&(df_train['Total Bsmt SF']>4000)].index, inplace=True)
df_train.drop(df_train[(df_train['SalePrice']<300000)&(df_train['1st Flr SF']>4000)].index, inplace=True)
df_train.drop(df_train[(df_train['SalePrice']<300000)&(df_train['Gr Liv Area']>4000)].index, inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12, 12))
plt.subplots_adjust(right=2)
plt.subplots_adjust(top=2)

for i, feature in enumerate(continuous_outliers,1):

    plt.subplot(len(continuous_outliers), 2, i)
    sns.scatterplot(x=feature, y='SalePrice', palette='Blues', data=df_train)     
    plt.xlabel('{}'.format(feature), size=15,labelpad=12.5)
    plt.ylabel('SalePrice', size=15, labelpad=12.5)
    
    for j in range(2):
        plt.tick_params(axis='x', labelsize=15)
        plt.tick_params(axis='y', labelsize=15)
        
plt.show()

# %%
df_train.drop(df_train[(df_train['SalePrice']>400000)&(df_train['Overall Qual']==6)].index, inplace=True)
df_train.drop(df_train[(df_train['SalePrice']>500000)&(df_train['Overall Qual']==8)].index, inplace=True)
df_train.drop(df_train[(df_train['SalePrice']>300000)&(df_train['Garage Cars']==1)].index, inplace=True)
df_train.drop(df_train[(df_train['SalePrice']>400000)&(df_train['Garage Cars']==4)].index, inplace=True)

# %%
fig,ax = plt.subplots(figsize=(20,12))
plt.subplots_adjust(right=2)
plt.subplots_adjust(top=2)

for i, feature in enumerate(Categorical_outliers,1):
    
    plt.subplot(len(Categorical_outliers), 1, i)
    sns.boxplot(x=feature, y='SalePrice', palette='Blues', data=df_train)     
    plt.xlabel('{}'.format(feature), size=25,labelpad=12.5)
    plt.ylabel('SalePrice', size=25, labelpad=12.5)
    for j in range(2):
        plt.tick_params(axis='x', labelsize=25)
        plt.tick_params(axis='y', labelsize=25)

plt.show()

# %%
mod_train_row = df_train.shape[0]

# %%
df_train[['MS SubClass','Yr Sold','Mo Sold']] = df_train[['MS SubClass','Yr Sold','Mo Sold']] .astype(str)

# %%
df_train[['MS SubClass','Yr Sold','Mo Sold']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1963 entries, 0 to 2050
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MS SubClass  1963 non-null   object
#  1   Yr Sold      1963 non-null   object
#  2   Mo Sold      1963 non-null   object
# dtypes: object(3)
# memory usage: 125.9+ KB

# %%
# Log-transformation of the target variable
y = np.log1p(df_train['SalePrice'])

(mu,sigma) = norm.fit(y)
print(f'mu = {round(mu,2)}, sigma = {round(sigma,2)}, skew = {y.skew()}')
f, ax = plt.subplots(figsize=(10,5))
ax = sns.distplot(y, fit=norm)
plt.xlabel('SalePrice', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.title('Distribution of Housing Sale Price after Log', fontsize=15)
plt.show()
# Out:
# mu = 12.03, sigma = 0.4, skew = -0.016827915295275202
# C:\Users\pkfei\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(f'The rows removed in data cleaning is {round(100*(ori_train_row-mod_train_row)/ori_train_row,2)}% of train dataset')
# Out:
# The rows removed in data cleaning is 4.29% of train dataset

# %%
df_train.head()
# Out:
#   MS SubClass MS Zoning  Lot Area Street Lot Shape Land Contour Utilities  \
# 0          60        RL     13517   Pave       IR1          Lvl    AllPub
# 1          60        RL     11492   Pave       IR1          Lvl    AllPub
# 2          20        RL      7922   Pave       Reg          Lvl    AllPub
# 3          60        RL      9802   Pave       Reg          Lvl    AllPub
# 4          50        RL     14235   Pave       IR1          Lvl    AllPub
#
#   Lot Config Land Slope Neighborhood  ... Open Porch SF Enclosed Porch  \
# 0    CulDSac        Gtl       Sawyer  ...            44              0
# 1    CulDSac        Gtl      SawyerW  ...            74              0
# 2     Inside        Gtl        NAmes  ...            52              0
# 3     Inside        Gtl       Timber  ...             0              0
# 4     Inside        Gtl      SawyerW  ...            59              0
#
#   3Ssn Porch Screen Porch  Pool Area  Misc Val  Mo Sold  Yr Sold Sale Type  \
# 0          0            0          0         0        3     2010       WD
# 1          0            0          0         0        4     2009       WD
# 2          0            0          0         0        1     2010       WD
# 3          0            0          0         0        4     2010       WD
# 4          0            0          0         0        3     2010       WD
#
#   SalePrice
# 0    130500
# 1    220000
# 2    109000
# 3    174000
# 4    138500
#
# [5 rows x 68 columns]

# %% [markdown]
# ## Pre-processing
# - One-hot encode categorical variables.
# - Train/test split your data.
# - Scale your data.
# - Consider using automated feature selection.

# %%
X = df_train.drop(columns='SalePrice')
y = np.log1p(df_train['SalePrice'])
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=42)
print(f'Before feature engineering, X training data shape:{X_train.shape},X testing data shape:{X_test.shape}')
# Out:
# Before feature engineering, X training data shape:(1472, 67),X testing data shape:(491, 67)

# %%
X_train.reset_index(drop=True,inplace=True)
X_test.reset_index(drop=True,inplace=True)
y_train.reset_index(drop=True,inplace=True)
y_test.reset_index(drop=True,inplace=True)

# %%
numeric_dtypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
def VIF_calculator(data):
  numeric = []
  for i in data.columns:
     if data[i].dtype in numeric_dtypes:
        numeric.append(i)
  X_coll = data[numeric]  
  vif_data = pd.DataFrame()
  vif_data['feature'] = X_coll.columns
  vif_data['VIF'] = [variance_inflation_factor(X_coll.values, i) for i in range(len(X_coll.columns))]

  return vif_data[vif_data['VIF']>10]

# %%
VIF_calculator(X_train)
# Out:
# C:\Users\pkfei\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#             feature           VIF
# 1      Overall Qual  6.163502e+01
# 2      Overall Cond  4.097099e+01
# 3        Year Built  1.364868e+04
# 4    Year Remod/Add  1.422443e+04
# 6      BsmtFin SF 1           inf
# 7      BsmtFin SF 2           inf
# 8       Bsmt Unf SF           inf
# 9     Total Bsmt SF           inf
# 10       1st Flr SF           inf
# 11       2nd Flr SF           inf
# 12  Low Qual Fin SF           inf
# 13      Gr Liv Area           inf
# 16        Full Bath  2.208885e+01
# 18    Bedroom AbvGr  3.282956e+01
# 19    Kitchen AbvGr  4.361844e+01
# 20    TotRms AbvGrd  8.260030e+01
# 22      Garage Cars  3.834072e+01
# 23      Garage Area  3.411298e+01

# %%
X_train['Total_garagearea'] = X_train['Garage Cars'] + X_train['Garage Area']
X_train['Quality&Cond'] = (X_train['Overall Qual']+X_train['Overall Cond'])
X_train = X_train.drop(columns=['Year Remod/Add','TotRms AbvGrd','Garage Cars','Garage Area','Overall Qual','Overall Cond',
                                'BsmtFin SF 1','BsmtFin SF 2','Bsmt Unf SF','1st Flr SF','2nd Flr SF','Low Qual Fin SF'])
# Out:
# C:\Users\pkfei\AppData\Local\Temp/ipykernel_26088/1549406876.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Total_garagearea'] = X_train['Garage Cars'] + X_train['Garage Area']
# C:\Users\pkfei\AppData\Local\Temp/ipykernel_26088/1549406876.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Quality&Cond'] = (X_train['Overall Qual']+X_train['Overall Cond'])

# %%
VIF_calculator(X_train)
# Out:
#              feature         VIF
# 1         Year Built  107.361950
# 3      Total Bsmt SF   17.682471
# 4        Gr Liv Area   46.171152
# 7          Full Bath   18.290923
# 9      Bedroom AbvGr   24.565213
# 10     Kitchen AbvGr   38.205128
# 19  Total_garagearea   10.372884
# 20      Quality&Cond   69.086091

# %%
def label_encode(data): 
 encode_feature=[]
 lbl = LabelEncoder()
 for i in data.columns:
    if data[i].dtype == object:
        encode_feature.append(i)
 for n in encode_feature:      
    data[n] = lbl.fit_transform(list(data[n].values))
 return data

# %%
X_train = label_encode(X_train)
sc = StandardScaler()
Z_train = pd.DataFrame(sc.fit_transform(X_train), columns=X_train.columns)

# %%
X_test['Total_garagearea'] = X_test['Garage Cars'] + X_test['Garage Area']
X_test['Quality&Cond'] = (X_test['Overall Qual']+X_test['Overall Cond'])
X_test = X_test.drop(columns=['Year Remod/Add','TotRms AbvGrd','Garage Cars','Garage Area','Overall Qual','Overall Cond',
                                'BsmtFin SF 1','BsmtFin SF 2','Bsmt Unf SF','1st Flr SF','2nd Flr SF','Low Qual Fin SF'])
# Out:
# C:\Users\pkfei\AppData\Local\Temp/ipykernel_26088/1439747357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Total_garagearea'] = X_test['Garage Cars'] + X_test['Garage Area']
# C:\Users\pkfei\AppData\Local\Temp/ipykernel_26088/1439747357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Quality&Cond'] = (X_test['Overall Qual']+X_test['Overall Cond'])

# %%
X_test = label_encode(X_test)
Z_test = pd.DataFrame(sc.transform(X_test),columns=X_test.columns)

# %%
print(f'After feature engineering, X training data shape:{Z_train.shape},X testing data shape:{Z_test.shape} while y training data shape:{y_train.shape}, y testing data shape:{y_test.shape}')
# Out:
# After feature engineering, X training data shape:(1472, 57),X testing data shape:(491, 57) while y training data shape:(1472,), y testing data shape:(491,)

# %%
X_statmodel = sm.add_constant(Z_train)
model = sm.OLS(y_train,X_statmodel)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     240.4
# Date:                Thu, 23 Jun 2022   Prob (F-statistic):               0.00
# Time:                        22:45:20   Log-Likelihood:                 1006.6
# No. Observations:                1472   AIC:                            -1899.
# Df Residuals:                    1415   BIC:                            -1597.
# Df Model:                          56
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               12.0269      0.003   3704.612      0.000      12.021      12.033
# MS SubClass          0.0065      0.006      1.118      0.264      -0.005       0.018
# MS Zoning           -0.0057      0.004     -1.538      0.124      -0.013       0.002
# Lot Area             0.0233      0.004      5.769      0.000       0.015       0.031
# Street               0.0075      0.003      2.232      0.026       0.001       0.014
# Lot Shape           -0.0064      0.004     -1.759      0.079      -0.014       0.001
# Land Contour        -0.0063      0.004     -1.686      0.092      -0.014       0.001
# Utilities        -3.931e-17   6.09e-18     -6.454      0.000   -5.13e-17   -2.74e-17
# Lot Config           0.0040      0.003      1.166      0.244      -0.003       0.011
# Land Slope           0.0023      0.004      0.576      0.565      -0.006       0.010
# Neighborhood         0.0005      0.004      0.142      0.887      -0.007       0.008
# Condition 1          0.0010      0.003      0.304      0.761      -0.006       0.008
# Condition 2         -0.0018      0.003     -0.524      0.600      -0.008       0.005
# Bldg Type           -0.0163      0.005     -3.288      0.001      -0.026      -0.007
# House Style         -0.0083      0.005     -1.679      0.093      -0.018       0.001
# Year Built           0.0819      0.008     10.339      0.000       0.066       0.097
# Roof Style           0.0046      0.004      1.284      0.199      -0.002       0.012
-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\pkfei\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
result.params.sort_values(ascending=False)
# Out:
# const               1.202694e+01
# Gr Liv Area         1.325437e-01
# Quality&Cond        9.817070e-02
# Year Built          8.190006e-02
# Total Bsmt SF       5.425250e-02
# Total_garagearea    2.881568e-02
# Bsmt Full Bath      2.672085e-02
# Lot Area            2.329303e-02
# Fireplaces          2.279046e-02
# Paved Drive         1.879460e-02
# Exterior 2nd        1.638837e-02
# Screen Porch        1.620982e-02
# Central Air         1.513966e-02
# Foundation          1.473299e-02
# Exter Cond          1.417061e-02
# Functional          1.386207e-02
# Enclosed Porch      1.357736e-02
# Mas Vnr Type        1.148762e-02
# Full Bath           1.058915e-02
# Street              7.523452e-03
# Mas Vnr Area        7.231850e-03
# MS SubClass         6.491295e-03
# Sale Type           6.363087e-03
# Wood Deck SF        5.332179e-03
# Bsmt Cond           5.228169e-03
# Roof Style          4.617375e-03
# Pool Area           4.562840e-03
# Lot Config          4.000096e-03
# 3Ssn Porch          3.111218e-03
# Misc Val            2.677236e-03
# Land Slope          2.299475e-03
# Electrical          1.645593e-03
# Bsmt Half Bath      1.495280e-03
# Mo Sold             1.294402e-03
# BsmtFin Type 2      1.256581e-03
# Condition 1         1.033201e-03
# Half Bath           8.185508e-04
# Neighborhood        5.119740e-04
# Open Porch SF       1.238021e-04
# Utilities          -3.931388e-17
# Condition 2        -1.767341e-03
# MS Zoning          -5.656208e-03
# Roof Matl          -5.986266e-03
# Bedroom AbvGr      -6.172156e-03
# Land Contour       -6.254246e-03
# Lot Shape          -6.441733e-03
# Heating            -7.102852e-03
# Bsmt Qual          -7.522817e-03
# House Style        -8.276007e-03
# Bsmt Exposure      -9.256963e-03
# Yr Sold            -1.041195e-02
# Kitchen Qual       -1.143701e-02
# Exterior 1st       -1.160493e-02
# Kitchen AbvGr      -1.265510e-02
# Heating QC         -1.444854e-02
# BsmtFin Type 1     -1.467064e-02
# Bldg Type          -1.632166e-02
# Exter Qual         -1.725630e-02
# dtype: float64

# %% [markdown]
# ## Modeling
# - **Establish your baseline score.**
# - Fit linear regression. Look at your coefficients. Are any of them wildly overblown?
# - Fit lasso/ridge/elastic net with default parameters.
# - Go back and remove features that might be causing issues in your models.
# - Tune hyperparameters.
# - **Identify a production model.** (This does not have to be your best performing Kaggle model, but rather the model that best answers your problem statement.)
# - Refine and interpret your production model.

# %%
lr = LinearRegression()
lr.fit(Z_train, y_train)
y_train_pred_lr = lr.predict(Z_train)
y_test_pred_lr = lr.predict(Z_test)

# %%
mse_train = mean_squared_error(y_train, y_train_pred_lr)
mse_test = mean_squared_error(y_test, y_test_pred_lr)

perc_diff = (mse_train - mse_test)/mse_train * 100
print(mse_train, mse_test, str(perc_diff)+"%")
# Out:
# 0.014914136350356119 7.721047213998066e+20 -5.176999212437603e+24%

# %%
l_alphas=np.logspace(-3,10,100)

lasso_cv = LassoCV(alphas=l_alphas, cv=3, max_iter=50000)
lasso_model = lasso_cv.fit(Z_train, y_train)
y_train_pred_la = lasso_model.predict(Z_train)
y_test_pred_la = lasso_model.predict(Z_test)

print(lasso_cv.alpha_)
mse_train = mean_squared_error(y_train, y_train_pred_la)
mse_test = mean_squared_error(y_test, y_test_pred_la)

perc_diff = (mse_train - mse_test)/mse_train * 100
print(mse_train, mse_test, str(perc_diff)+"%")
# Out:
# 0.0024770763559917113
# 0.015176074626116443 0.015404625306028999 -1.5059933846084557%

# %%
lasso_model.coef_
# Out:
# array([ 0.00000000e+00, -3.44364523e-03,  2.19351798e-02,  4.43464571e-03,
#        -5.54607085e-03, -5.08713463e-03,  0.00000000e+00,  2.45444704e-05,
#         4.54971688e-04,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#        -1.62720501e-02, -0.00000000e+00,  8.00874219e-02,  1.86612231e-03,
#        -2.06382615e-03, -0.00000000e+00,  4.69898420e-03,  6.91141175e-03,
#         4.17951427e-03, -1.69968517e-02,  1.30158691e-02,  1.50504913e-02,
#        -8.51795776e-03,  2.07052906e-03, -7.65939535e-03, -1.26447083e-02,
#         0.00000000e+00,  5.77736124e-02, -4.68450654e-03, -1.45037169e-02,
#         1.47116854e-02,  0.00000000e+00,  1.27936251e-01,  2.52198320e-02,
#         0.00000000e+00,  6.50487880e-03,  0.00000000e+00, -0.00000000e+00,
#        -1.01237807e-02, -1.23195823e-02,  9.91659864e-03,  2.40289351e-02,
#         1.74808421e-02,  4.29365120e-03,  0.00000000e+00,  9.22566621e-03,
#         4.81367073e-04,  1.34490037e-02,  1.39406613e-03,  1.32635558e-04,
#         0.00000000e+00, -7.75143662e-03,  3.69037120e-03,  2.98701895e-02,
#         9.97325260e-02])

# %% [markdown]
# ## Predicting result

# %%
df_test.head()
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0          190        RM          69.0      9142   Pave  Grvl       Reg
# 1           90        RL           NaN      9662   Pave   NaN       IR1
# 2           60        RL          58.0     17104   Pave   NaN       IR1
# 3           30        RM          60.0      8520   Pave   NaN       Reg
# 4           20        RL           NaN      9500   Pave   NaN       IR1
#
#   Land Contour Utilities Lot Config  ... 3Ssn Porch Screen Porch Pool Area  \
# 0          Lvl    AllPub     Inside  ...          0            0         0
# 1          Lvl    AllPub     Inside  ...          0            0         0
# 2          Lvl    AllPub     Inside  ...          0            0         0
# 3          Lvl    AllPub     Inside  ...          0            0         0
# 4          Lvl    AllPub     Inside  ...          0          185         0
#
#   Pool QC Fence Misc Feature  Misc Val  Mo Sold  Yr Sold  Sale Type
# 0     NaN   NaN          NaN         0        4     2006        WD
# 1     NaN   NaN          NaN         0        8     2006        WD
# 2     NaN   NaN          NaN         0        9     2006        New
# 3     NaN   NaN          NaN         0        7     2007        WD
# 4     NaN   NaN          NaN         0        7     2009        WD
#
# [5 rows x 78 columns]

# %%
df_test=df_test.fillna(df_test.mean())
df_test=df_test.fillna(0)
df_test.isnull().sum()
# Out:
# C:\Users\pkfei\AppData\Local\Temp/ipykernel_26088/811488006.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_test=df_test.fillna(df_test.mean())
# MS SubClass     0
# MS Zoning       0
# Lot Frontage    0
# Lot Area        0
# Street          0
#                ..
# Misc Feature    0
# Misc Val        0
# Mo Sold         0
# Yr Sold         0
# Sale Type       0
# Length: 78, dtype: int64

# %%
test_feature=[]
for i in df_test.columns:
    if i not in columns_dropped:
        test_feature.append(i)

# %%
df_test = df_test[test_feature]

# %%
df_test[['MS SubClass','Yr Sold','Mo Sold']] = df_test[['MS SubClass','Yr Sold','Mo Sold']] .astype(str)

# %%
df_test['Total_garagearea'] = df_test['Garage Cars'] + df_test['Garage Area']
df_test['Quality&Cond'] = (df_test['Overall Qual']+df_test['Overall Cond'])
df_test = df_test.drop(columns=['Year Remod/Add','TotRms AbvGrd','Garage Cars','Garage Area','Overall Qual','Overall Cond',
                                'BsmtFin SF 1','BsmtFin SF 2','Bsmt Unf SF','1st Flr SF','2nd Flr SF','Low Qual Fin SF'])

# %%
df_test = label_encode(df_test)
df_test = pd.DataFrame(sc.transform(df_test),columns=df_test.columns)

# %%
df_test
# Out:
#      MS SubClass  MS Zoning  Lot Area  Street  Lot Shape  Land Contour  \
# 0      -1.103451   2.956319 -0.118413  0.0522   0.756612      0.312094
# 1       1.941381   1.458315 -0.044366  0.0522  -1.364783      0.312094
# 2       0.557367   1.458315  1.015361  0.0522  -1.364783      0.312094
# 3      -0.549845   2.956319 -0.206984  0.0522   0.756612      0.312094
# 4      -0.826648   1.458315 -0.067434  0.0522  -1.364783      0.312094
# ..           ...        ...       ...     ...        ...           ...
# 873     0.557367   1.458315 -0.281031  0.0522   0.756612      0.312094
# 874     0.557367   1.458315  0.668764  0.0522   0.756612      0.312094
# 875    -0.826648   1.458315 -0.245432  0.0522   0.756612      0.312094
# 876    -0.826648   1.458315 -0.138633  0.0522   0.756612      0.312094
# 877    -0.826648   1.458315 -0.224072  0.0522   0.756612      0.312094
#
#      Utilities  Lot Config  Land Slope  Neighborhood  ...  Enclosed Porch  \
# 0          0.0    0.573992   -0.216525      0.632972  ...        1.521221
# 1          0.0    0.573992   -0.216525      0.927779  ...       -0.376797
# 2          0.0    0.573992   -0.216525     -0.841059  ...       -0.376797
# 3          0.0    0.573992   -0.216525      0.632972  ...        2.741376
# 4          0.0    0.573992   -0.216525     -0.104043  ...       -0.376797
# ..         ...         ...         ...           ...  ...             ...
# 873        0.0    0.573992   -0.216525      0.190763  ...       -0.376797
# 874        0.0    0.573992   -0.216525     -0.104043  ...       -0.376797
# 875        0.0    0.573992   -0.216525      0.927779  ...       -0.376797
# 876        0.0   -0.693699   -0.216525     -0.104043  ...       -0.376797
# 877        0.0   -1.961391   -0.216525     -0.104043  ...       -0.376797
#
#      3Ssn Porch  Screen Porch  Pool Area  Misc Val   Mo Sold   Yr Sold  \
# 0     -0.094509     -0.281732  -0.054247 -0.097831 -0.170275 -1.322754
# 1     -0.094509     -0.281732  -0.054247 -0.097831  1.166500 -1.322754
# 2     -0.094509     -0.281732  -0.054247 -0.097831  1.500694 -1.322754
# 3     -0.094509     -0.281732  -0.054247 -0.097831  0.832306 -0.565424
# 4     -0.094509      3.071324  -0.054247 -0.097831  0.832306  0.949234
# ..          ...           ...        ...       ...       ...       ...
#        12.23837515, 12.09740955, 12.39880141, 11.73155186, 12.06433965,
#        11.96287806, 11.82662226, 11.87711493, 11.85157192, 11.63545886,
#        12.27055498, 12.0894232 , 11.85998391, 11.58538246, 12.12383849,
#        11.88326086, 12.11119424, 12.21246172, 11.66462446, 12.64814684,
#        12.41430993, 11.88997491, 11.80043988, 11.87572814, 11.76514506,
#        11.6386998 , 13.0850334 , 11.2818192 , 11.88581983, 12.11971912,
#        11.85583864, 12.27924268, 11.66518973, 12.3159403 , 12.03723176,
#        12.62190364, 11.9248939 , 12.13099769, 12.64750724, 11.88540415,
#        12.32124847, 11.93556758, 11.75438318, 12.29019017, 11.53850768,
#        11.84141484, 12.17181404, 11.81964026, 11.774465  , 11.93941088,
#        11.9486677 , 12.80122197, 11.32022105, 11.68819578, 11.70376681,
#        11.88496843, 12.42030532, 11.68005262, 12.52007881, 12.03705057,
#        12.03183775, 12.36825247, 12.00804564, 12.50038661, 11.90158994,
#        12.13882895, 11.9056654 , 12.20533057, 12.34655736, 12.12503307,
#        11.64897447, 11.52024597, 11.96945734, 11.1631083 , 12.36083655,
#        11.5018868 , 11.55417096, 12.04691311, 11.77952449, 11.61944931,
#        11.81099442, 12.60961198, 11.77676738, 11.91157493, 12.23375794,
#        12.13057545, 12.18819483, 11.31646999, 11.52507105, 11.86422054,
#        11.89468616, 11.55002267, 12.80490077, 11.62341578, 11.98629726,
#        12.11477938, 12.90386598, 11.87564852, 11.97662565, 11.71698486,
#        11.94735507, 11.78059842, 12.4668    , 12.12936268, 11.64311862,
#        11.7076064 , 12.54317963, 11.83463999, 11.74301219, 11.686239  ,
#        12.13614067, 12.03906624, 12.28430756, 11.70666817, 11.98847254,
#        11.95349237, 12.33067949, 12.28083924, 11.6410097 , 11.91535574,
#        11.87278639, 11.90257181, 11.73591453, 11.77135161, 11.92451668,
#        11.43883539, 12.20525802, 11.54722608, 12.08865229, 11.60963984,
#        12.76286417, 11.7405879 , 11.61086577, 11.95201932, 11.85423216,
#        12.05646615, 12.09029059, 12.21523068, 11.84320326, 11.88402485,
#        12.34829911, 12.60629123, 12.19082222, 12.10773274, 12.17955026,
#        11.70487684, 11.60312586, 11.63238998])

# %%
sales_predict = np.expm1(y_predict)
sales_predict.shape
# Out:
# (878,)

# %%
df_train['SalePrice']
# Out:
# 0       130500
# 1       220000
# 2       109000
# 3       174000
# 4       138500
#          ...
# 2046    298751
# 2047     82500
# 2048    177000
# 2049    144000
# 2050    189000
# Name: SalePrice, Length: 1963, dtype: int64

# %%
sub = pd.DataFrame()
sub['Id'] = test_id
sub['SalePrice'] = sales_predict
sub.to_csv('./datasets/submission.csv',index=False)

# %%
test_id
# Out:
# 0      2658
# 1      2718
# 2      2414
# 3      1989
# 4       625
#        ...
# 873    1662
# 874    1234
# 875    1373
# 876    1672
# 877    1939
# Name: Id, Length: 878, dtype: int64

# %% [markdown]
# ## Inferential Visualizations
# - Look at feature loadings.
# - Look at how accurate your predictions are.
# - Is there a pattern to your errors? Consider reworking your model to address this.
